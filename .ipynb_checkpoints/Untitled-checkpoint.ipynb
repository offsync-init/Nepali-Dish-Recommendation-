# %%
import pandas as pd
import numpy as np
import nltk
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
dataset = pd.read_csv('nepali_food_500_dishes.csv')
dataset.set_index('ID' , inplace =True , drop = True)
dataset.sample(3)
# Out:
#     Item Name   Category Primary Ingredients Origin/Context  \
# ID
# 2        Bhat     Staple        Steamed Rice          Nepal
# 83     Barela  Vegetable        Balsam Apple    Rural Nepal
# 360    Bhelka       Soup           Vegetable      Rajbanshi
#
#                                            Description
# ID
# 2    Plain boiled rice, the central component of th...
# 83   A gourd-like vegetable often sautéed with spices.
# 360  A light vegetable broth of the Rajbanshi commu...

# %%
dataset.isna().sum()
# Out:
# Item Name              0
# Category               0
# Primary Ingredients    0
# Origin/Context         0
# Description            0
# dtype: int64

# %%
from nltk.corpus import stopwords
# StopWords initialisation
stop_words =stopwords.words('english')
#Stemmer 
stemmer = PorterStemmer()

# DataCleaner
def Clean_Description(text):
    text = re.sub(r'[^\w\s]', '', text)
    text = " ".join([stemmer.stem(words.lower()) for words in nltk.word_tokenize(text) if words not in stop_words and len(words) > 2])
    return text

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

Vectoriser = TfidfVectorizer(
    preprocessor=Clean_Description,
    ngram_range=(1,3),
    max_features=2000
)

# %%
vector_space = Vectoriser.fit_transform(dataset['Description'])

# %%
# Out:
#                                                      0
# 0    <Compressed Sparse Row sparse matrix of dtype ...
# 1    <Compressed Sparse Row sparse matrix of dtype ...
# 2    <Compressed Sparse Row sparse matrix of dtype ...
# 3    <Compressed Sparse Row sparse matrix of dtype ...
# 4    <Compressed Sparse Row sparse matrix of dtype ...
# ..                                                 ...
# 495  <Compressed Sparse Row sparse matrix of dtype ...
# 496  <Compressed Sparse Row sparse matrix of dtype ...
# 497  <Compressed Sparse Row sparse matrix of dtype ...
# 498  <Compressed Sparse Row sparse matrix of dtype ...
# 499  <Compressed Sparse Row sparse matrix of dtype ...
#
# [500 rows x 1 columns]
